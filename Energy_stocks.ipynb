# %%
#analysis of returns of major energy and mining companies in India with data obtained from yahoo finance
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
from pandas_datareader import data

symbol = 'HINDALCO.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfhindalco = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'COALINDIA.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfcoalindia = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'NTPC.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfntpc = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'VEDL.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfvedanta = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'JSWSTEEL.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfjsw = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'BPCL.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfbpcl = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'IOC.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfioc = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'TATASTEEL.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dftatasteel = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'GAIL.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfgail = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'POWERGRID.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfpowergrid = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'ONGC.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfongc = data.DataReader(symbol, data_source, start_date, end_date)

# %%
symbol = 'RELIANCE.NS'
data_source='yahoo'
start_date = '2009-01-01'
end_date = '2019-12-31'

dfreliance = data.DataReader(symbol, data_source, start_date, end_date)

# %%
df = pd.concat([dfhindalco,dfcoalindia,dfntpc,dfvedanta,dfjsw,dfbpcl,dfioc,dftatasteel,dfgail,dfpowergrid,dfongc,dfreliance],keys=['HINDALCO','COAL INDIA','NTPC','VEDANTA','JSW','BPCL','IOC','TATA STEEL','GAIL','POWERGRID','ONGC','RELIANCE'],names=['CompanyName','Date'])
df.head()
# Out:
#                              High        Low       Open      Close  \
# CompanyName Date
# HINDALCO    2009-01-02  57.250000  54.900002  54.900002  56.049999
#             2009-01-05  59.349998  56.400002  57.000000  58.150002
#             2009-01-06  60.150002  56.599998  58.849998  58.099998
#             2009-01-07  60.950001  53.250000  59.650002  54.799999
#             2009-01-09  55.900002  51.799999  54.000000  52.599998
#
#                             Volume  Adj Close
# CompanyName Date
# HINDALCO    2009-01-02  11835593.0  50.712513
#             2009-01-05   8918730.0  52.612549
#             2009-01-06   6678525.0  52.567303
#             2009-01-07   8695748.0  49.581554
#             2009-01-09   3406603.0  47.591045

# %%
##df.loc[(['SBI','HDFC','ICICI','AXIS'],['2009-01-02','2020-04-09']),['Close','Volume']]
df1 = df.reset_index( drop=False)

df1.head()
# Out:
#   CompanyName       Date       High        Low       Open      Close  \
# 0    HINDALCO 2009-01-02  57.250000  54.900002  54.900002  56.049999
009-04-08T00:00:00.000000000", "2009-04-09T00:00:00.000000000", "2009-04-13T00:00:00.000000000", "2009-04-15T00:00:00.000000000", "2009-04-16T00:00:00.000000000", "2009-04-17T00:00:00.000000000", "2009-04-20T00:00:00.000000000", "2009-04-21T00:00:00.000000000", "2009-04-22T00:00:00.000000000", "2009-04-23T00:00:00.000000000", "2009-04-24T00:00:00.000000000", "2009-04-27T00:00:00.000000000", "2009-04-28T00:00:00.000000000", "2009-04-29T00:00:00.000000000", "2009-04-30T00:00:00.000000000", "2009-05-04T00:00:00.000000000", "2009-05-05T00:00:00.000000000", "2009-05-06T00:00:00.000000000", "2009-05-07T00:00:00.000000000", "2009-05-08T00:00:00.000000000", "2009-05-11T00:00:00.000000000", "2009-05-12T00:00:00.000000000", "2009-05-13T00:00:00.000000000", "2009-05-14T00:00:00.000000000", "2009-05-15T00:00:00.000000000", "2009-05-18T00:00:00.000000000", "2009-05-19T00:00:00.000000000", "2009-05-20T00:00:00.000000000", "2009-05-21T00:00:00.000000000", "2009-05-22T00:00:00.000000000", "2009-05-25T00:00:00.000000000", "2009-05-26T00:00:00.000000000", "2009-05-27T00:00:00.000000000", "2009-05-28T00:00:00.000000000", "2009-05-29T00:00:00.000000000", "2009-06-01T00:00:00.000000000", "2009-06-02T00:00:00.000000000", "2009-06-03T00:00:00.000000000", "2009-06-04T00:00:00.000000000", "2009-06-05T00:00:00.000000000", "2009-06-08T00:00:00.000000000", "2009-06-09T00:00:00.000000000", "2009-06-10T00:00:00.000000000", "2009-06-11T00:00:00.000000000", "2009-06-12T00:00:00.000000000", "2009-06-15T00:00:00.000000000", "2009-06-16T00:00:00.000000000", "2009-06-17T00:00:00.000000000", "2009-06-18T00:00:00.000000000", "2009-06-19T00:00:00.000000000", "2009-06-22T00:00:00.000000000", "2009-06-23T00:00:00.000000000", "2009-06-24T00:00:00.00000000 ...

# %%
yearlist=[2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
datelist=list(df1[df1['Date']=='2009-01-02']['Date'].unique())
returns=pd.DataFrame()
#returns=pd.
for i in yearlist:
    datelist.append(df1[df1['Date'].apply(lambda x:x.year)==i]['Date'].max())
    
for j in datelist:
    returns =pd.concat([returns,df1[df1['Date']==j][['CompanyName','Date','Adj Close']]])
returns.reset_index(inplace=True,drop=True)
returns.rename(columns={'Adj Close':'Price'},inplace=True)
companylist=returns['CompanyName'].unique()
returns_pct_change=pd.DataFrame()
returns.set_index(['CompanyName','Date'],inplace=True)
return_pct_change=pd.DataFrame()
for k in  companylist:
    return_pct_change = pd.concat([return_pct_change,returns.loc[k].pct_change()],axis=1)
    return_pct_change.rename(columns={'Price':k},inplace=True)
    
return_pct_change.to_excel('Energy_Returns.xlsx','Energy')

# %%
yearlist=[2019]
datelist=list(df1[df1['Date']=='2009-01-02']['Date'].unique())
returns=pd.DataFrame()
#returns=pd.
for i in yearlist:
    datelist.append(df1[df1['Date'].apply(lambda x:x.year)==i]['Date'].max())
    
for j in datelist:
    returns =pd.concat([returns,df1[df1['Date']==j][['CompanyName','Date','Adj Close']]])
returns.reset_index(inplace=True,drop=True)
returns.rename(columns={'Adj Close':'Price'},inplace=True)
companylist=returns['CompanyName'].unique()
returns_pct_change=pd.DataFrame()
returns.set_index(['CompanyName','Date'],inplace=True)
return_pct_change_absolute=pd.DataFrame()
for k in  companylist:
    return_pct_change_absolute = pd.concat([return_pct_change_absolute,returns.loc[k].pct_change()],axis=1)
    return_pct_change_absolute.rename(columns={'Price':k},inplace=True)
    

return_pct_change_absolute.to_excel('Energy_Returns_absolute.xlsx','Energy')
